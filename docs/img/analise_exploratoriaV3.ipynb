# %% [markdown]
# # Análise Explorátoria
# Usamos os dados do dataset obtido no Kaggle: https://www.kaggle.com/datasets/catherinerasgaitis/mxmh-survey-results

# %%
#Importar Bibliotecas

import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
#Importar base de dados

df = pd.read_csv("C:\Puc\db_musica_saude.csv")

# %%
#Retorna o número de linhas pelo número de colunas do meu conjunto de dados.

print(df.shape)
# Out:
# (736, 33)

# %%
#Retorna o tipo das colunas e a quantidade de valores não nulos que temos nelas.

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Timestamp                     736 non-null    object
#  1   Age                           735 non-null    float64
#  2   Primary streaming service     735 non-null    object
#  3   Hours per day                 736 non-null    float64
#  4   While working                 733 non-null    object
#  5   Instrumentalist               732 non-null    object
#  6   Composer                      735 non-null    object
#  7   Fav genre                     736 non-null    object
#  8   Exploratory                   736 non-null    object
#  9   Foreign languages             732 non-null    object
#  10  BPM                           629 non-null    float64
#  11  Frequency [Classical]         736 non-null    object
#  12  Frequency [Country]           736 non-null    object
#  13  Frequency [EDM]               736 non-null    object
#  14  Frequency [Folk]              736 non-null    object
#  15  Frequency [Gospel]            736 non-null    object
#  16  Frequency [Hip hop]           736 non-null    object
#  17  Frequency [Jazz]              736 non-null    object
#  18  Frequency [K pop]             736 non-null    object
#  19  Frequency [Latin]             736 non-null    object
#  20  Frequency [Lofi]              736 non-null    object
#  21  Frequency [Metal]             736 non-null    object
#  22  Frequency [Pop]               736 non-null    object
#  23  Frequency [R&B]               736 non-null    object
#  24  Frequency [Rap]               736 non-null    object
#  25  Frequency [Rock]              736 non-null    object
#  26  Frequency [Video game music]  736 non-null    object
#  27  Anxiety                       736 non-null    float64
#  28  Depression                    736 non-null    float64
#  29  Insomnia                      736 non-null    float64
#  30  OCD                           736 non-null    float64
#  31  Music effects                 728 non-null    object
#  32  Permissions                   736 non-null    object
# dtypes: float64(7), object(26)
# memory usage: 189.9+ KB
# None

# %%
#Retorna o nome de todas as suas colunas no conjunto de dados.

print(df.columns)
# Out:
# Index(['Timestamp', 'Age', 'Primary streaming service', 'Hours per day',
#        'While working', 'Instrumentalist', 'Composer', 'Fav genre',
#        'Exploratory', 'Foreign languages', 'BPM', 'Frequency [Classical]',
#        'Frequency [Country]', 'Frequency [EDM]', 'Frequency [Folk]',
#        'Frequency [Gospel]', 'Frequency [Hip hop]', 'Frequency [Jazz]',
#        'Frequency [K pop]', 'Frequency [Latin]', 'Frequency [Lofi]',
#        'Frequency [Metal]', 'Frequency [Pop]', 'Frequency [R&B]',
#        'Frequency [Rap]', 'Frequency [Rock]', 'Frequency [Video game music]',
#        'Anxiety', 'Depression', 'Insomnia', 'OCD', 'Music effects',
#        'Permissions'],
#       dtype='object')

# %%
#Retorna as primeiras 5 linhas do meu conjunto de dados.

print(df.head())
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 0               Yes  ...        Sometimes  Very frequently            Never
# 1                No  ...        Sometimes           Rarely  Very frequently
# 2               Yes  ...            Never           Rarely           Rarely
# 3               Yes  ...        Sometimes            Never            Never
# 4                No  ...  Very frequently  Very frequently            Never
#
#   Frequency [Video game music] Anxiety Depression Insomnia  OCD Music effects  \
# 0                    Sometimes     3.0        0.0      1.0  0.0           NaN
# 1                       Rarely     7.0        2.0      2.0  1.0           NaN
# 2              Very frequently     7.0        7.0     10.0  2.0     No effect
# 3                        Never     9.0        7.0      3.0  3.0       Improve
# 4                       Rarely     7.0        2.0      5.0  9.0       Improve
#
#      Permissions
# 0  I understand.
# 1  I understand.
# 2  I understand.
# 3  I understand.
# 4  I understand.
#
# [5 rows x 33 columns]

# %%
#Descobrindo valores nulos

df.isnull().sum()
# Out:
# Timestamp                         0
# Age                               1
# Primary streaming service         1
# Hours per day                     0
# While working                     3
# Instrumentalist                   4
# Composer                          1
# Fav genre                         0
# Exploratory                       0
# Foreign languages                 4
# BPM                             107
# Frequency [Classical]             0
# Frequency [Country]               0
# Frequency [EDM]                   0
# Frequency [Folk]                  0
# Frequency [Gospel]                0
# Frequency [Hip hop]               0
# Frequency [Jazz]                  0
# Frequency [K pop]                 0
# Frequency [Latin]                 0
# Frequency [Lofi]                  0
# Frequency [Metal]                 0
# Frequency [Pop]                   0
# Frequency [R&B]                   0
# Frequency [Rap]                   0
# Frequency [Rock]                  0
# Frequency [Video game music]      0
# Anxiety                           0
# Depression                        0
# Insomnia                          0
# OCD                               0
# Music effects                     8
# Permissions                       0
# dtype: int64

# %%
#função que gera uma gráfico de barras com colunas e frequência dos dados faltantes.

def missing_visualization(df):
  quant_isnull = df.isnull().sum()
  columns = df.columns
  dic = {"colunas":[],"quant_isnull":[]}
  for coluna,quant in zip(columns,quant_isnull):
    if quant > 0:
      dic["colunas"].append(quant)
      dic["quant_isnull"].append(coluna)
  df = pd.DataFrame(dic)
  plt.figure(figsize=(15,5))
  sns.barplot(x=df["quant_isnull"],y=df["colunas"],data=df, palette="rocket")
  plt.xticks(rotation=45);

# %%
missing_visualization(df)

# %%
# Exclundo a coluna Permissions


df = df.drop('Permissions', axis=1)

# %%
#Resume a contagem, média, desvio padrão, mínimo e máximo para variáveis numéricas. Estatistica Descritiva com as variaveis numericas 

df.describe()
# Out:
#               Age  Hours per day           BPM     Anxiety  Depression  \
# count  735.000000     736.000000  6.290000e+02  736.000000  736.000000
# mean    25.206803       3.572758  1.589948e+06    5.837636    4.796196
# std     12.054970       3.028199  3.987261e+07    2.793054    3.028870
# min     10.000000       0.000000  0.000000e+00    0.000000    0.000000
# 25%     18.000000       2.000000  1.000000e+02    4.000000    2.000000
# 50%     21.000000       3.000000  1.200000e+02    6.000000    5.000000
# 75%     28.000000       5.000000  1.440000e+02    8.000000    7.000000
# max     89.000000      24.000000  1.000000e+09   10.000000   10.000000
#
#          Insomnia         OCD
# count  736.000000  736.000000
# mean     3.738451    2.637228
# std      3.088689    2.842017
# min      0.000000    0.000000
# 25%      1.000000    0.000000
# 50%      3.000000    2.000000
# 75%      6.000000    5.000000
# max     10.000000   10.000000

# %%
df.plot(kind='box', figsize=(10,6), subplots=True)
# Out:
# Age                 AxesSubplot(0.125,0.11;0.0945122x0.77)
# Hours per day    AxesSubplot(0.238415,0.11;0.0945122x0.77)
# BPM              AxesSubplot(0.351829,0.11;0.0945122x0.77)
# Anxiety          AxesSubplot(0.465244,0.11;0.0945122x0.77)
# Depression       AxesSubplot(0.578659,0.11;0.0945122x0.77)
# Insomnia         AxesSubplot(0.692073,0.11;0.0945122x0.77)
# OCD              AxesSubplot(0.805488,0.11;0.0945122x0.77)
# dtype: object

# %%
# Criar histograma da idade
plt.figure(figsize=(10, 6))  # Definir o tamanho da figura
plt.hist(df['Age'], bins=10, edgecolor='black', color='orange')  # Gerar histograma

# Adicionar título e rótulos aos eixos
plt.title('Histograma da Distribuição de Idades', fontsize=16)
plt.xlabel('Idade', fontsize=14)
plt.ylabel('Frequência', fontsize=14)

# Exibir o gráfico
plt.show()

# %% [markdown]
# # Analisando os outliers

# %%
df[df['Age'] >= 40]
# Out:
#               Timestamp   Age          Primary streaming service  \
# 1    8/27/2022 19:57:31  63.0                            Pandora
# 3    8/27/2022 21:40:40  61.0                      YouTube Music
# 57   8/28/2022 13:08:24  42.0  I do not use a streaming service.
# 68   8/28/2022 13:55:45  41.0                        Apple Music
# 91   8/28/2022 14:47:08  43.0  I do not use a streaming service.
# ..                  ...   ...                                ...
# 636  9/12/2022 19:41:23  42.0                            Spotify
# 643   9/13/2022 0:48:14  42.0            Other streaming service
# 654  9/13/2022 11:16:37  43.0  I do not use a streaming service.
# 695  9/28/2022 17:25:48  89.0                            Spotify
# 703  10/3/2022 11:30:10  44.0                      YouTube Music
#
#      Hours per day While working Instrumentalist Composer         Fav genre  \
# 1             1.50           Yes              No       No              Rock
# 3             2.50           Yes              No      Yes              Jazz
# 57            0.00           NaN              No       No              Rock
# 68            3.00           Yes             Yes      Yes             Metal
# 91            6.00           Yes             Yes      Yes  Video game music
# ..             ...           ...             ...      ...               ...
# 636           2.00           Yes              No       No             Metal
# 643           0.25            No             Yes       No         Classical
# 654           0.00            No              No       No              Rock
# 695          24.00           Yes             Yes      Yes               Rap
# 703           1.50            No              No       No              Folk
#
#     Exploratory Foreign languages  ...  Frequency [Pop] Frequency [R&B]  \
# 1           Yes                No  ...        Sometimes       Sometimes
# 3           Yes               Yes  ...        Sometimes       Sometimes
# 57           No               Yes  ...           Rarely          Rarely
# 68          Yes               Yes  ...        Sometimes           Never
# 91          Yes               Yes  ...        Sometimes          Rarely
# ..          ...               ...  ...              ...             ...
# 636         Yes               Yes  ...  Very frequently       Sometimes
# 643         Yes               Yes  ...        Sometimes          Rarely
# 654          No                No  ...        Sometimes          Rarely
# 695          No                No  ...           Rarely       Sometimes
# 703          No                No  ...           Rarely          Rarely
#
#      Frequency [Rap] Frequency [Rock] Frequency [Video game music] Anxiety  \
# 1             Rarely  Very frequently                       Rarely     7.0
# 3              Never            Never                        Never     9.0
# 57             Never        Sometimes                    Sometimes     9.0
# 68            Rarely           Rarely                        Never    10.0
# 91             Never        Sometimes              Very frequently     5.0
# ..               ...              ...                          ...     ...
# 636            Never  Very frequently              Very frequently     7.0
# 643           Rarely        Sometimes                        Never     7.0
# 654           Rarely        Sometimes                        Never     1.0
# 695  Very frequently           Rarely                        Never     0.0
# 703        Sometimes        Sometimes                        Never     8.0
#
#     Depression Insomnia  OCD Music effects
# 1          2.0      2.0  1.0           NaN
# 3          7.0      3.0  3.0       Improve
# 57         0.0     10.0  0.0     No effect
# 68         7.0      8.0  0.0       Improve
# 91         4.0      8.0  3.0     No effect
# ..         ...      ...  ...           ...
# 636        8.0      5.0  3.0       Improve
# 643        9.0      4.0  5.0       Improve
# 654        2.0      2.0  0.0     No effect
# 695        0.0      0.0  0.0     No effect
# 703        5.0      9.0  4.0       Improve
#
# [78 rows x 32 columns]

# %%
df[df['Hours per day'] >= 8]
# Out:
#                Timestamp   Age Primary streaming service  Hours per day  \
# 11    8/27/2022 23:00:32  19.0             YouTube Music            8.0
# 16    8/27/2022 23:39:41  16.0                   Spotify            8.0
# 17    8/27/2022 23:39:49  16.0                   Spotify           12.0
# 18    8/27/2022 23:40:55  17.0                   Spotify           24.0
# 20    8/27/2022 23:43:06  15.0               Apple Music            8.0
# ..                   ...   ...                       ...            ...
# 695   9/28/2022 17:25:48  89.0                   Spotify           24.0
# 699    10/3/2022 9:30:19  16.0                   Spotify            9.0
# 710    10/4/2022 4:50:49  16.0                   Spotify            8.0
# 713   10/4/2022 14:50:28  17.0             YouTube Music            8.0
# 726  10/23/2022 20:50:27  18.0               Apple Music           18.0
#
#     While working Instrumentalist Composer Fav genre Exploratory  \
# 11            Yes              No       No       EDM         Yes
# 16            Yes              No       No   Hip hop         Yes
# 17            Yes              No      Yes   Hip hop         Yes
# 18            Yes              No       No       Rap         Yes
# 20            Yes              No       No   Hip hop         Yes
# ..            ...             ...      ...       ...         ...
# 695           Yes             Yes      Yes       Rap          No
# 699           Yes              No       No     Metal          No
# 710           Yes             Yes      Yes      Rock         Yes
# 713           Yes              No       No       Pop         Yes
# 726           Yes              No       No       EDM         Yes
#
#     Foreign languages  ...  Frequency [Pop] Frequency [R&B]  Frequency [Rap]  \
# 11                 No  ...           Rarely          Rarely        Sometimes
# 16                Yes  ...            Never       Sometimes  Very frequently
# 17                Yes  ...        Sometimes          Rarely        Sometimes
# 18                 No  ...           Rarely       Sometimes  Very frequently
# 20                Yes  ...  Very frequently          Rarely  Very frequently
# ..                ...  ...              ...             ...              ...
# 695                No  ...           Rarely       Sometimes  Very frequently
# 699               Yes  ...        Sometimes          Rarely           Rarely
# 710                No  ...        Sometimes          Rarely            Never
# 713               Yes  ...  Very frequently           Never           Rarely
# 726                No  ...           Rarely       Sometimes        Sometimes
#
#     Frequency [Rock] Frequency [Video game music] Anxiety Depression Insomnia  \
# 11            Rarely                       Rarely     1.0        0.0      0.0
# 16             Never                       Rarely     8.0        8.0      4.0
# 17   Very frequently                        Never     5.0        7.0     10.0
# 18   Very frequently                        Never     7.0        5.0      0.0
# 20         Sometimes                    Sometimes     6.0        9.0      3.0
# ..               ...                          ...     ...        ...      ...
# 695           Rarely                        Never     0.0        0.0      0.0
# 699  Very frequently                        Never    10.0       10.0     10.0
# 710  Very frequently                    Sometimes     8.0        9.0      5.0
# 713           Rarely              Very frequently     5.0        2.0      4.0
# 726        Sometimes                    Sometimes     9.0        8.0      5.0
#
#       OCD Music effects
# 11    1.0       Improve
# 16    3.0       Improve
# 17    0.0       Improve
# 18    3.0       Improve
# 20    0.0       Improve
# ..    ...           ...
# 695   0.0     No effect
# 699   8.0       Improve
# 710  10.0       Improve
# 713   7.0     No effect
# 726  10.0       Improve
#
# [72 rows x 32 columns]

# %% [markdown]
# # Correlação de Pearson entre a variável "Hours per day" e as variáveis de saúde mental (Anxiety, Depression, etc.):

# %%
# Selecionar colunas de interesse
health_vars = ['Anxiety', 'Depression', 'Insomnia','OCD']
df_clean = df[['Hours per day'] + health_vars].dropna()

# Verificar tipos de dados
print(df_clean.dtypes)

# Análise de Correlação de Pearson
print("Correlação de Pearson:")
for var in health_vars:
    corr, p_value = pearsonr(df_clean['Hours per day'], df_clean[var])
    print(f' - "Hours per day" vs {var}: Corr = {corr:.3f}, p-valor = {p_value:.3f}')

# Visualizar a matriz de correlação
corr_matrix = df_clean[['Hours per day'] + health_vars].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlação')
plt.show()
# Out:
# Hours per day    float64
# Anxiety          float64
# Depression       float64
# Insomnia         float64
# OCD              float64
# dtype: object
# Correlação de Pearson:
#  - "Hours per day" vs Anxiety: Corr = 0.049, p-valor = 0.181
#  - "Hours per day" vs Depression: Corr = 0.111, p-valor = 0.003
#  - "Hours per day" vs Insomnia: Corr = 0.142, p-valor = 0.000
#  - "Hours per day" vs OCD: Corr = 0.119, p-valor = 0.001

# %% [markdown]
# # Tabela de Frequência

# %%
# Contar a frequência absoluta de cada gênero musical
freq_absoluta = df['Fav genre'].value_counts()

# Calcular a frequência relativa
freq_relativa = df['Fav genre'].value_counts(normalize=True)

# Calcular a frequência acumulada
freq_acumulada = freq_relativa.cumsum()

# Criar uma tabela consolidada
tabela_frequencia = pd.DataFrame({
    'Frequência Absoluta': freq_absoluta,
    'Frequência Relativa (%)': freq_relativa * 100,
    'Frequência Acumulada (%)': freq_acumulada * 100
})

# Exibir a tabela de frequência
tabela_frequencia
# Out:
#                   Frequência Absoluta  Frequência Relativa (%)  \
# Rock                              188                25.543478
# Pop                               114                15.489130
# Metal                              88                11.956522
# Classical                          53                 7.201087
# Video game music                   44                 5.978261
# EDM                                37                 5.027174
# R&B                                35                 4.755435
# Hip hop                            35                 4.755435
# Folk                               30                 4.076087
# K pop                              26                 3.532609
# Country                            25                 3.396739
# Rap                                22                 2.989130
# Jazz                               20                 2.717391
# Lofi                               10                 1.358696
# Gospel                              6                 0.815217
# Latin                               3                 0.407609
#
#                   Frequência Acumulada (%)
# Rock                             25.543478
# Pop                              41.032609
# Metal                            52.989130
# Classical                        60.190217
# Video game music                 66.168478
# EDM                              71.195652
# R&B                              75.951087
# Hip hop                          80.706522
# Folk                             84.782609
# K pop                            88.315217
# Country                          91.711957
# Rap                              94.701087
# Jazz                             97.418478
# Lofi                             98.777174
# Gospel                           99.592391
# Latin                           100.000000

# %%
# Filtrar colunas relacionadas a frequências musicais

musical_styles_columns = [col for col in df.columns if col.startswith('Frequency')]

# %%
def calculate_frequencies(data, column):
    
    # Frequência absoluta
    abs_freq = data[column].value_counts().sort_index()
    
    # Frequência relativa
    rel_freq = (abs_freq / abs_freq.sum()) * 100
    
    # Frequência acumulada
    cum_freq = abs_freq.cumsum()
    
    # Montar DataFrame final
    freq_table = pd.DataFrame({
        'Frequência Absoluta': abs_freq,
        'Frequência Relativa (%)': rel_freq,
        'Frequência Acumulada': cum_freq
    })
    
    return freq_table

# %% [markdown]
# # Tabela de Frequencia para o estilo musical Classical

# %%
# Dicionário para armazenar as tabelas de frequência de cada estilo
frequencies_dict = {}

# Gerar a tabela para cada estilo musical
for style in musical_styles_columns:
    frequencies_dict[style] = calculate_frequencies(df, style)

# Exibir a tabela de frequência para um estilo musical específico (por exemplo, "Classical")
frequencies_dict['Frequency [Classical]']
# Out:
#                  Frequência Absoluta  Frequência Relativa (%)  \
# Never                            169                22.961957
# Rarely                           259                35.190217
# Sometimes                        200                27.173913
# Very frequently                  108                14.673913
#
#                  Frequência Acumulada
# Never                             169
# Rarely                            428
# Sometimes                         628
# Very frequently                   736

# %% [markdown]
# # Tabela de Frequencia para o estilo musical Country

# %%
# Dicionário para armazenar as tabelas de frequência de cada estilo
frequencies_dict = {}

# Gerar a tabela para cada estilo musical
for style in musical_styles_columns:
    frequencies_dict[style] = calculate_frequencies(df, style)

# Exibir a tabela de frequência para um estilo musical específico (por exemplo, "Classical")
frequencies_dict['Frequency [Country]']
# Out:
#                  Frequência Absoluta  Frequência Relativa (%)  \
# Never                            343                46.603261
# Rarely                           233                31.657609
# Sometimes                        111                15.081522
# Very frequently                   49                 6.657609
#
#                  Frequência Acumulada
# Never                             343
# Rarely                            576
# Sometimes                         687
# Very frequently                   736

# %% [markdown]
# # Tabela de Frequencia para o estilo musical EDM

# %%
# Dicionário para armazenar as tabelas de frequência de cada estilo
frequencies_dict = {}

# Gerar a tabela para cada estilo musical
for style in musical_styles_columns:
    frequencies_dict[style] = calculate_frequencies(df, style)

# Exibir a tabela de frequência para um estilo musical específico (por exemplo, "Classical")
frequencies_dict['Frequency [EDM]']
# Out:
#                  Frequência Absoluta  Frequência Relativa (%)  \
# Never                            307                41.711957
# Rarely                           194                26.358696
# Sometimes                        146                19.836957
# Very frequently                   89                12.092391
#
#                  Frequência Acumulada
# Never                             307
# Rarely                            501
# Sometimes                         647
# Very frequently                   736

# %% [markdown]
# # Tabela de Frequencia para o estilo musical Folk

# %%
# Dicionário para armazenar as tabelas de frequência de cada estilo
frequencies_dict = {}

# Gerar a tabela para cada estilo musical
for style in musical_styles_columns:
    frequencies_dict[style] = calculate_frequencies(df, style)

# Exibir a tabela de frequência para um estilo musical específico (por exemplo, "Classical")
frequencies_dict['Frequency [Folk]']
# Out:
#                  Frequência Absoluta  Frequência Relativa (%)  \
# Never                            292                39.673913
# Rarely                           221                30.027174
# Sometimes                        145                19.701087
# Very frequently                   78                10.597826
#
#                  Frequência Acumulada
# Never                             292
# Rarely                            513
# Sometimes                         658
# Very frequently                   736

# %%
# Tabela de Frequencia para o estilo musical Gospel

# %%
# Dicionário para armazenar as tabelas de frequência de cada estilo
frequencies_dict = {}

# Gerar a tabela para cada estilo musical
for style in musical_styles_columns:
    frequencies_dict[style] = calculate_frequencies(df, style)

# Exibir a tabela de frequência para um estilo musical específico (por exemplo, "Classical")
frequencies_dict['Frequency [Gospel]']
# Out:
#                  Frequência Absoluta  Frequência Relativa (%)  \
# Never                            535                72.690217
# Rarely                           135                18.342391
# Sometimes                         52                 7.065217
# Very frequently                   14                 1.902174
#
#                  Frequência Acumulada
# Never                             535
# Rarely                            670
# Sometimes                         722
# Very frequently                   736

# %% [markdown]
# # Tabela de Frequencia para o estilo musical Hip hop

# %%
# Dicionário para armazenar as tabelas de frequência de cada estilo
frequencies_dict = {}

# Gerar a tabela para cada estilo musical
for style in musical_styles_columns:
    frequencies_dict[style] = calculate_frequencies(df, style)

# Exibir a tabela de frequência para um estilo musical específico (por exemplo, "Classical")
frequencies_dict['Frequency [Hip hop]']
# Out:
#                  Frequência Absoluta  Frequência Relativa (%)  \
# Never                            181                24.592391
# Rarely                           214                29.076087
# Sometimes                        218                29.619565
# Very frequently                  123                16.711957
#
#                  Frequência Acumulada
# Never                             181
# Rarely                            395
# Sometimes                         613
# Very frequently                   736

# %% [markdown]
# # Tabela de Frequencia para o estilo musical Jazz

# %%
# Dicionário para armazenar as tabelas de frequência de cada estilo
frequencies_dict = {}

# Gerar a tabela para cada estilo musical
for style in musical_styles_columns:
    frequencies_dict[style] = calculate_frequencies(df, style)

# Exibir a tabela de frequência para um estilo musical específico (por exemplo, "Classical")
frequencies_dict['Frequency [Jazz]']
# Out:
#                  Frequência Absoluta  Frequência Relativa (%)  \
# Never                            261                35.461957
# Rarely                           247                33.559783
# Sometimes                        175                23.777174
# Very frequently                   53                 7.201087
#
#                  Frequência Acumulada
# Never                             261
# Rarely                            508
# Sometimes                         683
# Very frequently                   736

# %% [markdown]
# # Tabela de Frequencia para o estilo musical K pop

# %%
# Dicionário para armazenar as tabelas de frequência de cada estilo
frequencies_dict = {}

# Gerar a tabela para cada estilo musical
for style in musical_styles_columns:
    frequencies_dict[style] = calculate_frequencies(df, style)

# Exibir a tabela de frequência para um estilo musical específico (por exemplo, "Classical")
frequencies_dict['Frequency [K pop]']
# Out:
#                  Frequência Absoluta  Frequência Relativa (%)  \
# Never                            416                56.521739
# Rarely                           176                23.913043
# Sometimes                         67                 9.103261
# Very frequently                   77                10.461957
#
#                  Frequência Acumulada
# Never                             416
# Rarely                            592
# Sometimes                         659
# Very frequently                   736

# %% [markdown]
# # Tabela de Frequencia para o estilo musical Latin

# %%
# Dicionário para armazenar as tabelas de frequência de cada estilo
frequencies_dict = {}

# Gerar a tabela para cada estilo musical
for style in musical_styles_columns:
    frequencies_dict[style] = calculate_frequencies(df, style)

# Exibir a tabela de frequência para um estilo musical específico (por exemplo, "Classical")
frequencies_dict['Frequency [Latin]']
# Out:
#                  Frequência Absoluta  Frequência Relativa (%)  \
# Never                            443                60.190217
# Rarely                           172                23.369565
# Sometimes                         88                11.956522
# Very frequently                   33                 4.483696
#
#                  Frequência Acumulada
# Never                             443
# Rarely                            615
# Sometimes                         703
# Very frequently                   736

# %%
# Tabela de Frequencia para o estilo musical Lofi

# %%
# Dicionário para armazenar as tabelas de frequência de cada estilo
frequencies_dict = {}

# Gerar a tabela para cada estilo musical
for style in musical_styles_columns:
    frequencies_dict[style] = calculate_frequencies(df, style)

# Exibir a tabela de frequência para um estilo musical específico (por exemplo, "Classical")
frequencies_dict['Frequency [Lofi]']
# Out:
#                  Frequência Absoluta  Frequência Relativa (%)  \
# Never                            280                38.043478
# Rarely                           211                28.668478
# Sometimes                        160                21.739130
# Very frequently                   85                11.548913
#
#                  Frequência Acumulada
# Never                             280
# Rarely                            491
# Sometimes                         651
# Very frequently                   736

# %% [markdown]
# # Tabela de Frequencia para o estilo musical Metal

# %%
# Dicionário para armazenar as tabelas de frequência de cada estilo
frequencies_dict = {}

# Gerar a tabela para cada estilo musical
for style in musical_styles_columns:
    frequencies_dict[style] = calculate_frequencies(df, style)

# Exibir a tabela de frequência para um estilo musical específico (por exemplo, "Classical")
frequencies_dict['Frequency [Metal]']
# Out:
#                  Frequência Absoluta  Frequência Relativa (%)  \
# Never                            264                35.869565
# Rarely                           192                26.086957
# Sometimes                        134                18.206522
# Very frequently                  146                19.836957
#
#                  Frequência Acumulada
# Never                             264
# Rarely                            456
# Sometimes                         590
# Very frequently                   736

# %% [markdown]
# # Tabela de Frequencia para o estilo musical Pop

# %%
# Dicionário para armazenar as tabelas de frequência de cada estilo
frequencies_dict = {}

# Gerar a tabela para cada estilo musical
for style in musical_styles_columns:
    frequencies_dict[style] = calculate_frequencies(df, style)

# Exibir a tabela de frequência para um estilo musical específico (por exemplo, "Classical")
frequencies_dict['Frequency [Pop]']
# Out:
#                  Frequência Absoluta  Frequência Relativa (%)  \
# Never                             56                 7.608696
# Rarely                           142                19.293478
# Sometimes                        261                35.461957
# Very frequently                  277                37.635870
#
#                  Frequência Acumulada
# Never                              56
# Rarely                            198
# Sometimes                         459
# Very frequently                   736

# %% [markdown]
# # Tabela de Frequencia para o estilo musical R&B

# %%
# Dicionário para armazenar as tabelas de frequência de cada estilo
frequencies_dict = {}

# Gerar a tabela para cada estilo musical
for style in musical_styles_columns:
    frequencies_dict[style] = calculate_frequencies(df, style)

# Exibir a tabela de frequência para um estilo musical específico (por exemplo, "Classical")
frequencies_dict['Frequency [R&B]']
# Out:
#                  Frequência Absoluta  Frequência Relativa (%)  \
# Never                            225                30.570652
# Rarely                           211                28.668478
# Sometimes                        184                25.000000
# Very frequently                  116                15.760870
#
#                  Frequência Acumulada
# Never                             225
# Rarely                            436
# Sometimes                         620
# Very frequently                   736

# %%
# Tabela de Frequencia para o estilo musical Rap

# %%
# Dicionário para armazenar as tabelas de frequência de cada estilo
frequencies_dict = {}

# Gerar a tabela para cada estilo musical
for style in musical_styles_columns:
    frequencies_dict[style] = calculate_frequencies(df, style)

# Exibir a tabela de frequência para um estilo musical específico (por exemplo, "Classical")
frequencies_dict['Frequency [Rap]']
# Out:
#                  Frequência Absoluta  Frequência Relativa (%)  \
# Never                            200                27.173913
# Rarely                           215                29.211957
# Sometimes                        195                26.494565
# Very frequently                  126                17.119565
#
#                  Frequência Acumulada
# Never                             200
# Rarely                            415
# Sometimes                         610
# Very frequently                   736

# %% [markdown]
# # Tabela de Frequencia para o estilo musical Rock

# %%
# Dicionário para armazenar as tabelas de frequência de cada estilo
frequencies_dict = {}

# Gerar a tabela para cada estilo musical
for style in musical_styles_columns:
    frequencies_dict[style] = calculate_frequencies(df, style)

# Exibir a tabela de frequência para um estilo musical específico (por exemplo, "Classical")
frequencies_dict['Frequency [Rock]']
# Out:
#                  Frequência Absoluta  Frequência Relativa (%)  \
# Never                             91                12.364130
# Rarely                            96                13.043478
# Sometimes                        219                29.755435
# Very frequently                  330                44.836957
#
#                  Frequência Acumulada
# Never                              91
# Rarely                            187
# Sometimes                         406
# Very frequently                   736

# %% [markdown]
# # Tabela de Frequencia para o estilo musical Video game music

# %%
# Dicionário para armazenar as tabelas de frequência de cada estilo
frequencies_dict = {}

# Gerar a tabela para cada estilo musical
for style in musical_styles_columns:
    frequencies_dict[style] = calculate_frequencies(df, style)

# Exibir a tabela de frequência para um estilo musical específico (por exemplo, "Classical")
frequencies_dict['Frequency [Video game music]']
# Out:
#                  Frequência Absoluta  Frequência Relativa (%)  \
# Never                            236                32.065217
# Rarely                           197                26.766304
# Sometimes                        186                25.271739
# Very frequently                  117                15.896739
#
#                  Frequência Acumulada
# Never                             236
# Rarely                            433
# Sometimes                         619
# Very frequently                   736

# %%
# Agrupar por quem escuta músicas em línguas estrangeiras e calcular a média de escores de saúde mental
foreign_language_impact = df.groupby('Foreign languages')[mental_health_cols].mean()

# Plotar gráfico de barras
foreign_language_impact.plot(kind='bar', figsize=(12, 6))
plt.title('Impacto de Escutar Músicas em Línguas Estrangeiras na Saúde Mental')
plt.ylabel('Média dos Escores de Saúde Mental')
plt.xticks(rotation=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16780\1971449706.py in <module>
#       1 # Agrupar por quem escuta músicas em línguas estrangeiras e calcular a média de escores de saúde mental
# ----> 2 foreign_language_impact = df.groupby('Foreign languages')[mental_health_cols].mean()
#       3
#       4 # Plotar gráfico de barras
#       5 foreign_language_impact.plot(kind='bar', figsize=(12, 6))
#
# NameError: name 'mental_health_cols' is not defined

# %%
# Agrupar por plataforma de streaming e calcular a média de horas por dia
streaming_hours = df.groupby('Primary streaming service')['Hours per day'].mean()

# Plotar gráfico de barras
streaming_hours.plot(kind='bar', color='skyblue', figsize=(10, 6))
plt.title('Média de Horas por Dia de Música por Plataforma de Streaming')
plt.ylabel('Média de Horas por Dia')
plt.xlabel('Plataforma de Streaming')
plt.show()

# %%
#Encontrando correlação entre as variáveis

df.describe()
# Out:
#               Age  Hours per day           BPM     Anxiety  Depression  \
# count  735.000000     736.000000  6.290000e+02  736.000000  736.000000
# mean    25.206803       3.572758  1.589948e+06    5.837636    4.796196
# std     12.054970       3.028199  3.987261e+07    2.793054    3.028870
# min     10.000000       0.000000  0.000000e+00    0.000000    0.000000
# 25%     18.000000       2.000000  1.000000e+02    4.000000    2.000000
# 50%     21.000000       3.000000  1.200000e+02    6.000000    5.000000
# 75%     28.000000       5.000000  1.440000e+02    8.000000    7.000000
# max     89.000000      24.000000  1.000000e+09   10.000000   10.000000
#
#          Insomnia         OCD
# count  736.000000  736.000000
# mean     3.738451    2.637228
# std      3.088689    2.842017
# min      0.000000    0.000000
# 25%      1.000000    0.000000
# 50%      3.000000    2.000000
# 75%      6.000000    5.000000
# max     10.000000   10.000000

# %%
corr_table = df.corr(method="pearson") #get variables the correlation

# %%
corr_table
# Out:
#                     Age  Hours per day       BPM   Anxiety  Depression  \
# Age            1.000000      -0.044638 -0.029928 -0.176662   -0.121563
# Hours per day -0.044638       1.000000  0.042554  0.049319    0.110527
# BPM           -0.029928       0.042554  1.000000 -0.027050    0.041371
# Anxiety       -0.176662       0.049319 -0.027050  1.000000    0.519969
# Depression    -0.121563       0.110527  0.041371  0.519969    1.000000
# Insomnia       0.006909       0.141821  0.053591  0.292669    0.378996
# OCD           -0.130114       0.118729  0.018927  0.348350    0.196988
#
#                Insomnia       OCD
# Age            0.006909 -0.130114
# Hours per day  0.141821  0.118729
# BPM            0.053591  0.018927
# Anxiety        0.292669  0.348350
# Depression     0.378996  0.196988
# Insomnia       1.000000  0.226354
# OCD            0.226354  1.000000

# %%
#Plotando a tabela de correlação usando o Seaborn.
plt.figure(figsize=(16,4))
sns.heatmap(corr_table, annot=True, fmt=".1g")
plt.title("Correlation Heatmap between variables")
plt.show() #mostrando o plot
