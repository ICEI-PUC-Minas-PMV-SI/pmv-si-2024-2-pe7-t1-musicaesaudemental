# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Carregando dataset
file_path = 'C:/Users/tulio/Downloads/dados_tratados_V2.csv'
data = pd.read_csv(file_path, delimiter=';')

# Informações iniciais
print(data.head())
print(data.info())

# Visualização da distribuição das frequências dos estilos musicais
style_columns = [col for col in data.columns if 'frequency' in col]
data[style_columns].hist(bins=15, figsize=(15, 10))
plt.show()

# Relação entre frequência de gêneros musicais e "Music effects"
sns.countplot(x='Music effects', data=data)
plt.show()

data_clean = data.dropna(subset=['Music effects'])

data_clean['Music effects'] = data_clean['Music effects'].map({'Improve': 1, 'No effect': 0, 'Worsen': -1})


# Define X e y
X = data[style_columns + ['Anxiety', 'Depression', 'Insomnia', 'OCD', 'Age']]
y = data['Music effects']

# Definir treinamento e teste do modelo
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Oversampling
train_data = pd.concat([X_train, y_train], axis=1)

# Separar por classe
class_counts = train_data['Music effects'].value_counts()
print("Contagem original das classes:\n", class_counts)

max_class = class_counts.max()  # Número de amostras na classe majoritária

# Reamostrar manualmente para equilibrar as classes
train_oversampled = pd.concat([
    train_data[train_data['Music effects'] == cls].sample(max_class, replace=True, random_state=42)
    for cls in class_counts.index
])

print("Contagem após oversampling:\n", train_oversampled['Music effects'].value_counts())

# Dividir X e y do conjunto reamostrado
X_train_oversampled = train_oversampled.drop(columns=['Music effects'])
y_train_oversampled = train_oversampled['Music effects']

# Definição de hiperparâmetros
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [5, 10, 15, 20, None],
    'min_samples_split': [2, 10, 20],
    'min_samples_leaf': [1, 5, 10]
}

# Treinamento do modelo
model = DecisionTreeClassifier(random_state=42)
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train_oversampled, y_train_oversampled)

# Parâmetros melhor avaliados
best_model = grid_search.best_estimator_
print("Melhores parâmetros:", grid_search.best_params_)

# Métricas
y_pred = best_model.predict(X_test)
print("Acurácia:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

# Matriz de confusão
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Worsen', 'No effect', 'Improve'], yticklabels=['Worsen', 'No effect', 'Improve'])
plt.title("Matriz de Confusão")
plt.ylabel('Real')
plt.xlabel('Previsto')
plt.show()

# Árvore de decisão
plt.figure(figsize=(100, 75))
plot_tree(best_model, feature_names=X.columns, class_names=['Worsen', 'Improve', 'No effect'], filled=True)
plt.show()
# Out:
#     Age Primary streaming service  Hours per day While working  \
# 0  18.0                   Spotify            4.0            No
# 1  61.0             YouTube Music            2.5           Yes
# 2  18.0                   Spotify            4.0           Yes
# 3  18.0                   Spotify            5.0           Yes
# 4  18.0             YouTube Music            3.0           Yes
#
#   Instrumentalist Composer         Fav genre Exploratory Foreign languages  \
# 0              No       No  Video game music          No               Yes
# 1              No      Yes              Jazz         Yes               Yes
# 2              No       No               R&B         Yes                No
# 3             Yes      Yes              Jazz         Yes               Yes
# 4             Yes       No  Video game music         Yes               Yes
#
#      BPM  ...  K pop_frequency  Latin_frequency  Lofi_frequency  \
# 0  132.0  ...                3                0               2
# 1   84.0  ...                2                3               2
# 2  107.0  ...                3                2               2
# 3   86.0  ...                3                1               3
# 4   66.0  ...                0                1               1
#
#    Metal_frequency Pop_frequency R&B_frequency Rap_frequency Rock_frequency  \
# 0                2             1             0             1              1
# 1                0             2             2             0              0
# 2                0             2             3             3              0
# 3                1             3             3             3              3
# 4                1             1             1             0              0
#
#   Video game music_frequency  Music effects
# 0                          3      No effect
# 1                          0        Improve
# 2                          1        Improve
# 3                          0        Improve
# 4                          2        Improve
#
# [5 rows x 36 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 612 entries, 0 to 611
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         612 non-null    float64
#  1   Primary streaming service   612 non-null    object
#  2   Hours per day               612 non-null    float64
#  3   While working               612 non-null    object
#  4   Instrumentalist             612 non-null    object
#  5   Composer                    612 non-null    object
#  6   Fav genre                   612 non-null    object
#  7   Exploratory                 612 non-null    object
#  8   Foreign languages           612 non-null    object
#  9   BPM                         612 non-null    float64
#  10  Anxiety                     612 non-null    float64
#  11  Depression                  612 non-null    float64
#  12  Insomnia                    612 non-null    float64
#  13  OCD                         612 non-null    float64
#  14  age_range                   612 non-null    object
#  15  Anxiety_level               612 non-null    object
#  16  Depression_level            612 non-null    object
#  17  Insomnia_level              612 non-null    object
#  18  OCD_level                   612 non-null    object
#  19  Classical_frequency         612 non-null    int64
#  20  Country_frequency           612 non-null    int64
#  21  EDM_frequency               612 non-null    int64
#  22  Folk_frequency              612 non-null    int64
#  23  Gospel_frequency            612 non-null    int64
#  24  Hip hop_frequency           612 non-null    int64
#  25  Jazz_frequency              612 non-null    int64
#  26  K pop_frequency             612 non-null    int64
#  27  Latin_frequency             612 non-null    int64
#  28  Lofi_frequency              612 non-null    int64
#  29  Metal_frequency             612 non-null    int64
#  30  Pop_frequency               612 non-null    int64
#  31  R&B_frequency               612 non-null    int64
#  32  Rap_frequency               612 non-null    int64
#  33  Rock_frequency              612 non-null    int64
#  34  Video game music_frequency  612 non-null    int64
#  35  Music effects               612 non-null    object
# dtypes: float64(7), int64(16), object(13)
# memory usage: 172.3+ KB
# None
# Contagem original das classes:
#  Music effects
# Improve      324
# No effect     94
# Worsen        10
# Name: count, dtype: int64
# Contagem após oversampling:
#  Music effects
# Improve      324
# No effect    324
# Worsen       324
# Name: count, dtype: int64
# Melhores parâmetros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Acurácia: 0.6358695652173914
#               precision    recall  f1-score   support
#
#      Improve       0.79      0.75      0.77       139
#    No effect       0.28      0.33      0.30        40
#       Worsen       0.00      0.00      0.00         5
#
#     accuracy                           0.64       184
#    macro avg       0.35      0.36      0.36       184
# weighted avg       0.66      0.64      0.64       184
